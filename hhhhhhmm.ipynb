# %%
1: 3572404 is divisible by 99

2: The remainder will be 0.

3: The two nearest numbers to 19506 which are divisible by 9 are:
19503 and 19515

4: M=7 and N=9

5: There are 3 pairs possible: (0,2), (9,0),(1,8)

6: The remainder will again be 3 as (6n)/8 = n/8 + n/8 = 3 + 3 = 3

7: P = 3

8: X = 0

9: n + 180

10: The largest possible value of M is 9 and smallest is 0. So, product
is 0*9 = 0

# %%
1: The unit digit in the product (365 x 659 x 771) is 5

2: The unit digit of the product (173)45*(152)77*(777)999 is 1

3: The unit`s digit of the number 6256–4256 is 6

4: The unit`s digit in 264102+264103 is 1

5: The unit digit of (316)3n + 1 is 1

6: The unit digit in (795 - 358) is 7

7: The rightmost non-zero digit of 302720 is 2

8: The last digit of the number obtained by multiplying 81828384868788*89 is 0

9: The last three digits of the product 12345x54321 is 468625

10: The last digit of 15+25+35......95 is 5

# %%
1: The highest power of 21 that divides 20! is 1
2: The highest power of 32 that divides 31! is 1
3: The largest number less than 28 that divides 28! is 21
4: 97! has 24 zeroes at the end
5: The highest power of 12 that divides 54! is 3
6: x = 35 makes 60!/2^x odd
7: n = 25
8: 7! divides 50! 7 times completely
9: 625! will have 1 more trailing zero than 624!
10: The number of zeroes at the end of 1×22×33×.....×100100 is 20001

# %%
1: The number of prime factors in 64x86x108x1410x2212 is 12

2: N has 3 perfect square factors (since a,b and c are 3 distinct primes)

3: 123x304x352 has 48 even factors

4: N and M have 2 common factors

5: (N-1) will have 4 factors

6: The smallest possible value of A is 2

7: 10! has 24 factors

8: There are 2 even perfect square factors of 27x36x54x73

9: 480 can be written as a product of two natural numbers in 24 ways

10: The number of factors of 25x34x53 that are not factors of 23x54x75 is 8

# %%
1: The remainder when 725 is divided by 6 is 5
2: The remainder when 345 is divided by 8 is 5
3: The remainder when 496 is divided by 6 is 4
4: The remainder when 141516 is divided by 5 is 1
5: The remainder when 6799 is divided by 7 is 5
6: The remainder when 73x75x78x57x197x37 is divided by 34 is 2
7: The remainder when N = 142114231425 is divided by 12 is 9
8: The remainder when 2256 is divided by 17 is 11
9: The remainder of 3997!/40 is 39
10: The remainder when 1! + 2! +3! ....+ 100! is divided by 7 is 1

# %%
a) 9600
b) 283
d) 16
a) 4
b) 7
c) 111
b) 80
c) 0.18
b) 2
c) 184
c) 23
b) 1683
c) 45 minutes
d) 345
c) 1260
b) 21 centimeters
c) 85
b) 127
c) 40
d) 42 centimeters
b) -1
c) 99
c) 11/120
c) 1001

# %%
1: 150
There are 100 numbers from 100 to 200. Out of these, 50 numbers end with 0 and 50 numbers end with 1, 5, or 6. So the total number of 1's is 150.

2: 96
There are 234 numbers from 259 to 492. Out of these, 23 numbers end with 8. So there will be 23*4 = 92 8's.

3: 19
If a is divided by 3, then quotient is b and remainder is 2.
Then b is divided by 3, then quotient is 2 and remainder is 1.
Starting with b = 2, work backwards:
b = 2
3 divides b, so b = 32 + 1 = 7
a = 37 + 2 = 19

4: 28
Let the number be n. Then:
n/5 has remainder 2
n/6 has remainder 1
Difference of quotients = 3
n/5 - n/6 = 3
Solve this to get n = 28

5: 0
The number formed is 12345678910111213...2829. Dividing this by 9 gives a remainder of 0.

6: 3:1
Let the original two digit number be 10a + b
75% of it is 7.5(10a + b) = 75a + 7.5b
When added to the original number, the reversed number is 10b + a
Equating the two numbers, we get:
75a + 7.5b = 10b + a
a = 3b
The ratio of unit digit to tens digit is 1:3

7: 38
Let the two digit number be 10a + b
ab = 8
18 is added to give the reversed number b +10a
Equating:
10a + b + 18 = b + 10a
18 = 10a - a
a = 8 and b = 5
The number is 38

8: The largest number
Product of 4 consecutive even numbers will always be divisible by the largest number
