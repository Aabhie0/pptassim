# %%
For Region A, we have the following sales data:

[10, 15, 12, 8, 14]

To find the mean sales for this region, we add up all the sales data and divide by the total number of sales data points.

Mean sales for Region A = (10 + 15 + 12 + 8 + 14) / 5 = 11.8

Therefore, the mean sales for Region A is 11.8.

Similarly, for Region B, we have the following sales data:

[18, 20, 16, 22, 25]

To find the mean sales for this region, we add up all the sales data and divide by the total number of sales data points.

Mean sales for Region B = (18 + 20 + 16 + 22 + 25) / 5 = 20.2

Therefore, the mean sales for Region B is 20.2

# %%
The mode is the value that appears most frequently in the dataset. In the survey responses provided, the number of times each value appears is:

2 appears twice
3 appears twice
4 appears three times
5 appears three times
Since both 4 and 5 appear three times, there are two modes in this dataset: 4 and 5. Therefore, the mode of the survey responses is 4 or 5

# %%
For Department A, we have the following salary data:

[5000, 6000, 5500, 7000]

To find the median salary for this department, we first need to arrange the data in order:

[5000, 5500, 6000, 7000]

The median salary is the middle value, which is 6000. Therefore, the median salary for Department A is 6000.

Similarly, for Department B, we have the following salary data:

[4500, 5500, 5800, 6000, 5200]

To find the median salary for this department, we first need to arrange the data in order:

[4500, 5200, 5500, 5800, 6000]

The median salary is the middle value, which is 5500. Therefore, the median salary for Department B is 5500

# %%
we need to find the difference between the highest and lowest values in the dataset.

The highest stock price in the dataset is 26.1, and the lowest stock price is 24.8. Therefore, the range of the stock prices is:

Range = Highest value - Lowest value
= 26.1 - 24.8
= 1.3

So, the range of the stock prices is 1.3

# %%
For Group A:
Mean (x̄A) = (85 + 90 + 92 + 88 + 91) / 5 = 89.2
Sample Standard Deviation (sA) = 2.98

For Group B:
Mean (x̄B) = (82 + 88 + 90 + 86 + 87) / 5 = 86.6
Sample Standard Deviation (sB) = 2.25

sp = sqrt(((nA - 1) * sA^2 + (nB - 1) * sB^2) / (nA + nB - 2))

where nA and nB are the sample sizes for Group A and Group B, respectively.

sp = sqrt(((5 - 1) * 2.98^2 + (5 - 1) * 2.25^2) / (5 + 5 - 2))
= 2.616
t = (x̄A - x̄B) / (sp * sqrt(1/nA + 1/nB))

t = (89.2 - 86.6) / (2.616 * sqrt(1/5 + 1/5))
= 1.17

Determine the degrees of freedom (df) using the formula:

df = nA + nB - 2

df = 5 + 5 - 2
= 8

For a two-tailed t-test with 8 degrees of freedom and a significance level of 0.05, the critical t-value is approximately 2.306 and the p-value is approximately 0.064

Since the calculated t-value of 1.17 is less than the critical t-value of 2.306, we fail to reject the null hypothesis. This means that there is not sufficient evidence to conclude that there is a significant difference in the mean scores between the two groups. The p-value of 0.064 is also greater than the significance level of 0.05, which further supports this conclusion. Therefore, we can conclude that the two teaching methods perform similarly in terms of their effect on student test scores

# %%
r = (nΣXY - ΣXΣY) / sqrt((nΣX^2 - (ΣX)^2)(nΣY^2 - (ΣY)^2))

n = 5
ΣX = 59
ΣY = 129
ΣXY = (10x25) + (15x30) + (12x28) + (8x20) + (14x26) = 2390
ΣX^2 = 10^2 + 15^2 + 12^2 + 8^2 + 14^2 = 645
ΣY^2 = 25^2 + 30^2 + 28^2 + 20^2 + 26^2 = 2705

Substituting these values into the formula, we get:

r = (5(2390) - (59)(129)) / sqrt((5(645) - (59)^2)(5(2705) - (129)^2))
= 0.862

# %%
s = sqrt(Σ(x - x̄)^2 / (n - 1))

where

x is the height of each person
x̄ is the mean height
n is the number of people in the sample.
Using the data provided, we can calculate the standard deviation as follows:

n = 7
x̄ = (160 + 170 + 165 + 155 + 175 + 180 + 170) / 7 = 167.14

deviations of each height from the mean:

160 - 167.14 = -7.14
170 - 167.14 = 2.86
165 - 167.14 = -2.14
155 - 167.14 = -12.14
175 - 167.14 = 7.86
180 - 167.14 = 12.86
170 - 167.14 = 2.86

Then, we can square each deviation and sum them up:

Σ(x - x̄)^2 = (-7.14)^2 + (2.86)^2 + (-2.14)^2 + (-12.14)^2 + (7.86)^2 + (12.86)^2 + (2.86)^2
= 1522.08

Substituting these values into the formula, we get:

s = sqrt(Σ(x - x̄)^2 / (n - 1))
= sqrt(1522.08 / 6)
= 11.31

# %%
the correlation coefficient as follows:

n = 7
ΣX = 26
ΣY = 48
ΣXY = (2x7) + (3x8) + (5x6) + (4x9) + (6x5) + (2x7) + (4x6) = 166
ΣX^2 = 2^2 + 3^2 + 5^2 + 4^2 + 6^2 + 2^2 + 4^2 = 90
ΣY^2 = 7^2 + 8^2 + 6^2 + 9^2 + 5^2 + 7^2 + 6^2 = 300

r = (nΣXY - ΣXΣY) / sqrt((nΣX^2 - (ΣX)^2)(nΣY^2 - (ΣY)^2))
= (7(166) - (26)(48)) / sqrt((7(90) - (26)^2)(7(300) - (48)^2))
= 0.0404

The correlation coefficient is positive, indicating a weak positive linear relationship between employee tenure and job satisfaction.

Step 3: Calculate the slope (b) and y-intercept (a) of the regression line using the formulas:

b = (nΣXY - ΣXΣY) / (nΣX^2 - (ΣX)^2)

a = (ΣY / n) - b(ΣX / n)

Substituting the values from the data, we get:

b = (7(166) - (26)(48)) / (7(90) - (26)^2) = 0.33

a = (48 / 7) - (0.33)(26 / 7) = 6.77

So, the regression equation is:

y = 0.33x + 6.77

where y represents job satisfaction and x represents employee tenure.

Step 4: Interpret the results and make predictions.

The slope of the regression line is 0.33, which means that for every one-year increase in employee tenure, job satisfaction is predicted to increase by 0.33 on average. The y-intercept of the regression line is 6.77, which represents the predicted job satisfaction score when the employee tenure is 0.

Using the regression equation, we can make predictions about job satisfaction based on employee tenure. For example, if an employee has a tenure of 7 years, we can predict their job satisfaction as:

y = 0.33(7) + 6.77 = 9.58

Therefore, we can predict that an employee with a tenure of 7 years will have a job satisfaction score of 9.58 on average. However, it is important to note that the correlation coefficient suggests a weak linear relationship between employee tenure and job satisfaction, so the predictions may not be very accurate

# %%
the mean of each group as follows:

Mean of Medication A = (10 + 12 + 14 + 11 + 13) / 5 = 12

Mean of Medication B = (15 + 17 + 16 + 14 + 18) / 5 = 16

the sum of squares between groups (SSB) using the formula:

SSB = Σ(ni * (yi - y)^2)

where

ni is the sample size of each group
yi is the mean of each group
y is the overall mean of the data.
Using the data provided, we can calculate the SSB as follows:

ni = 5
y = (12 + 16) / 2 = 14
SSB = 5 * ((12 - 14)^2 + (16 - 14)^2) = 40


sum of squares within groups (SSW) using the formula:

SSW = Σ((ni - 1) * si^2)

where si^2 is the variance of each group.

Using the data provided, we can calculate the variance of each group as follows:

Variance of Medication A = ((10 - 12)^2 + (12 - 12)^2 + (14 - 12)^2 + (11 - 12)^2 + (13 - 12)^2) / 4 = 1.5

Variance of Medication B = ((15 - 16)^2 + (17 - 16)^2 + (16 - 16)^2 + (14 - 16)^2 + (18 - 16)^2) / 4 = 2

Using the variances, we can calculate the SSW as follows:

SSW = (5 - 1) * 1.5 + (5 - 1) * 2 = 18


 degrees of freedom between groups (dfB) and within groups (dfW) using the formulas:

dfB = k - 1

dfW = N - k

where k is the number of groups and N is the total sample size.

Using the data provided, we can calculate the degrees of freedom as follows:

k = 2
N = 10
dfB = 2 - 1 = 1
dfW = 10 - 2 = 8

the mean square between groups (MSB) and mean square within groups (MSW) using the formulas:

MSB = SSB / dfB

MSW = SSW / dfW

Using the values we calculated, we can calculate the mean square as follows:

MSB = 40 / 1 = 40

MSW = 18 / 8 = 2.25



F-statistic using the formula:

F = MSB / MSW

Using the values we calculated, we can calculate the F-statistic as follows:

F = 40 / 2.25 = 17.78


Using an F-distribution table with 1 and 8 degrees of freedom for the numerator and denominator, respectively, we can find that the p-value associated with the F-statistic of 17.78 is less than 0.01


Interpret the results and make a conclusion.

Since the p-value associated with the F-statistic is less than 0.05, we can conclude that there is a significant difference in the mean recovery times between Medication A and Medication B. In other words, the two medications have different effects on recovery

# %%
The 75th percentile represents the value below which 75% of the data falls.

Using the data provided, we can arrange the ratings in ascending order as follows:

6, 7, 7, 8, 8, 8, 8, 9, 9, 10

To find the 75th percentile, we can use the following formula:

75th percentile = ((75/100) * n)th value

where n is the total number of data points.

Using the data provided, we have n = 10. Substituting the values, we get:

75th percentile = ((75/100) * 10)th value
= 7.5th value

Since 7.5 is not a whole number, we need to take the average of the 7th and 8th values to find the 75th percentile.

The 7th value is 8, and the 8th value is 9. Therefore, the 75th percentile is:

75th percentile = (8 + 9) / 2
= 8.5

Therefore, the 75th percentile of the feedback ratings is 8.5. This means that 75% of the feedback ratings are 8 or below, and 25% of the ratings are 9 or above

# %%
State the null and alternative hypotheses.

The null hypothesis (H0) is that the mean weight of the product is equal to 10 grams.

H0: μ = 10

The alternative hypothesis (HA) is that the mean weight of the product differs from 10 grams.

HA: μ ≠ 10

 Determine the level of significance (α) and the test statistic.

Assuming a significance level of 0.05, we need to calculate the test statistic, which is the t-statistic. The t-statistic is calculated using the formula:

t = (x̄ - μ) / (s / sqrt(n))

where x̄ is the sample mean, μ is the population mean (which is assumed to be 10), s is the sample standard deviation, and n is the sample size.

Using the data provided, we can calculate the sample mean and standard deviation as follows:

x̄ = (10.2 + 9.8 + 10.0 + 10.5 + 10.3 + 10.1) / 6 = 10.2

s = sqrt(((10.2 - 10)^2 + (9.8 - 10)^2 + (10.0 - 10)^2 + (10.5 - 10)^2 + (10.3 - 10)^2 + (10.1 - 10)^2) / 5) = 0.251

Substituting the values, we get:

t = (10.2 - 10) / (0.251 / sqrt(6)) = 1.697

The degrees of freedom (df) for the t-distribution are n - 1 = 6 - 1 = 5



Determine the p-value.

Using a t-distribution table with 5 degrees of freedom, we can find that the two-tailed p-value associated with a t-statistic of 1.697 is approximately 0.145

Make a decision and interpret the results.

Since the p-value (0.145) is greater than the significance level (0.05), we fail to reject the null hypothesis. This means that there is not enough evidence to conclude that the mean weight of the product differs significantly from 10 grams at a significance level of 0.05.

Therefore, we can conclude that the data does not provide sufficient evidence to suggest that the mean weight of the product is different from 10 grams

# %%
Define the null and alternative hypotheses.

The null hypothesis (H0) is that there is no significant difference in the click-through rates between the two designs.

H0: The click-through rates for Design A and Design B are the same.

The alternative hypothesis (HA) is that there is a significant difference in the click-through rates between the two designs.

HA: The click-through rates for Design A and Design B are different

Set the level of significance (α).

Assuming a significance level of 0.05, we need to determine if the calculated chi-square statistic is greater than the critical value of the chi-square distribution with 1 degree of freedom (df)


Expected frequency = (row total * column total) / grand total

Using the data provided, we can calculate the expected frequencies for each cell as follows:

Expected frequency for Design A and click = (515 * 5) / 1000 = 25.75
Expected frequency for Design A and no click = (485 * 5) / 1000 = 24.25
Expected frequency for Design B and click = (515 * 5) / 1000 = 25.75
Expected frequency for Design B and no click = (485 * 5) / 1000 = 24.25


The chi-square statistic can be calculated using the following formula:

χ2 = Σ((O - E)^2 / E)

where Σ represents the sum of all cells, O represents the observed frequency for each cell, and E represents the expected frequency for each cell

chi-square statistic as follows:

χ2 = ((100 - 25.75)^2 / 25.75) + ((120 - 25.75)^2 / 25.75) + ((110 - 25.75)^2 / 25.75) + ((90 - 24.25)^2 / 24.25) + ((95 - 24.25)^2 / 24.25) + ((80 - 25.75)^2 / 25.75) + ((85 - 25.75)^2 / 25.75) + ((90 - 25.75)^2 / 25.75) + ((95 - 24.25)^2 / 24.25) + ((100 - 24.25)^2 / 24.25)
= 9.155


Determine the critical value and the p-value.

Using a chi-square distribution table with 1 degree of freedom and a significance level of 0.05, we can find that the critical value is 3.84.

Using a chi-square distribution table with 1 degree of freedom, we can find that the p-value associated with a chi-square statistic of 9.155 is approximately 0.003

# %%
we can use the following formula:

CI = x̄ ± (tα/2 * (s / sqrt(n)))

where x̄ is the sample mean, tα/2 is the t-score associated with the desired level of confidence and the degrees of freedom (df), s is the sample standard deviation, and n is the sample size.

Using the data provided, we can calculate the sample mean and sample standard deviation as follows:

x̄ = (7 + 9 + 6 + 8 + 10 + 7 + 8 + 9 + 7 + 8) / 10 = 7.9
s = sqrt(((7 - 7.9)^2 + (9 - 7.9)^2 + (6 - 7.9)^2 + (8 - 7.9)^2 + (10 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2 + (9 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2) / 9) = 1.055

The degrees of freedom (df) for a t-distribution are n - 1 = 10 - 1 = 9. Using a t-distribution table with 9 degrees of freedom and a significance level of 0.05, the t-score associated with a 95% confidence interval is approximately 2.262.

Substituting the values, we get:

CI = 7.9 ± (2.262 * (1.055 / sqrt(10)))
= (6.12, 9.68)

Therefore, the 95% confidence interval for the population mean satisfaction score is (6.12, 9.68). This means that we can be 95% confident that the true population mean satisfaction score falls between 6.12 and 9.68

# %%
 correlation coefficient as follows:

r = (nΣxy - ΣxΣy) / sqrt((nΣx^2 - (Σx)^2)(nΣy^2 - (Σy)^2))
= (5*(-2) + 31 + 92 + 1*(-1) + 70) / sqrt((5401 - 85^2) * (5*79 - 31^2))
= 0.866

The correlation coefficient is positive and close to 1, which suggests a strong positive linear relationship between temperature and performance

Fit the linear regression model
We can fit a linear regression model to the data to predict performance based on temperature. The linear regression model takes the form:

y = β0 + β1x + ε

where y is the response variable (i.e., performance), x is the predictor variable (i.e., temperature), β0 is the intercept, β1 is the slope coefficient, and ε is the error term.

Using the given data, we can use statistical software such as R or Python to fit the linear regression model to the data. The output of the model will include estimates of the intercept and slope coefficients, as well as measures of model fit such as the R-squared value and p-values for the coefficients.

The linear regression model for the given data is:

y = 3.6 + 0.4x

where y is the predicted performance score, x is the temperature in degrees Celsius, 3.6 is the intercept, and 0.4 is the slope coefficient

We can evaluate the linear regression model to determine how well it fits the data. One way to do this is to look at the R-squared value, which represents the proportion of variance in the response variable that is explained by the predictor variable. A high R-squared value indicates that the model explains a large proportion of the variation in the response variable.

Using the given data, the R-squared value for the linear regression model is 0.75, which indicates that the model explains 75% of the variation in performance based on temperature.

In summary, the simple linear regression model to predict performance based on temperature for the given data is y = 3.6 + 0.4x, where y is the predicted performance score and x is the temperature in degrees Celsius. The model suggests a strong positive linear relationship between temperature and performance, with an R-squared value of 0.75 indicating that the model explains a large proportion of the variation in performance based on temperature
